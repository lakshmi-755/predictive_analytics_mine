# %% [markdown]
# <a href="https://colab.research.google.com/github/lakshmi-755/predictive_analytics_mine/blob/newbranch/predictive_analytics.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>
